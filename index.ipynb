# %% [markdown]
# # Analysis of intervals between startup milestones
#
# This notebook provides an analysis of the time interval between various milestones in the development of our startups. In particular, it assesses the time between GRA investments (Phase I, II, and III) and how that might relate to participation in I-Corps.
#
# The input data in the notebook was extracted from Salesforce.

# %%
# %matplotlib inline
import pandas
import numpy as np
import matplotlib
import datetime

# %%
# These are the ISO-8601 formatted date fields in the input file; we'll want Pandas to parse these as dates.
date_fields = [
    'first_touch_date',
    'incorporated_date',
    'icorps_end_date',
    'gra_1_inv_date',
    'gra_2_inv_date',
    'gra_3_inv_date',
    'sbir_inv_date',
]

# %%
def ndays(d):
    return None if pandas.isnull(d) else d.days

# %%
# Date when the I-Corps program got underway; we distinguish between teams before and after this date.
icorps_start_date = datetime.date(2012,1,1)

# %%
with open('data_in/vl-intervals.csv') as csv:
    df = pandas.read_csv(csv, parse_dates=date_fields, infer_datetime_format=True)

# %%
# Establish the interval columns
df['touch_to_gra_1_days'] = map(ndays, df['gra_1_inv_date'] - df['first_touch_date'])
df['icorps_to_gra_1_days'] = map(ndays, df['gra_1_inv_date'] - df['icorps_end_date'])
df['gra_1_to_gra_2_days'] = map(ndays, df['gra_2_inv_date'] - df['gra_1_inv_date'])
df['gra_2_to_gra_3_days'] = map(ndays, df['gra_3_inv_date'] - df['gra_2_inv_date'])

# %%
df
# Out:
#                                                  name  \
# 0                                             GTronix
# 1                                 Singhose - Controll
# 2                               ChemCore Therapeutics
# 3                                           Orthonics
# 4                                             BISmark
# 5                                  GaN bipolar switch
# 6                                CameRad Technologies
# 7                             Coreopsys Software Labs
# 8                                          LiquidText
# 9                                         Social Gaze
# 10                                           Trivalve
# 11                                         Prionomics
# 12                                            MEMScan
# 13                                           Audiallo
# 14                                          Bioletics
# 15                                           Surentez
# 16                                          HDConnect
# 17                                    Plum Combustion
# 18                                   GTC (Factory IS)
# 19                                     Tumor Monorail
# 20                        Terminal Velocity Aerospace
# 21                                          Tacticity
# 22                                          Polytherm
# 23                                                AGL
# 24                                            Pramana
# 25                          Reduced Graphite Oxide PV
# 26                                Reversible Grasping
# 27                       Doolittle - Aligned Crystals
# 28                       Ultrafast All Optical Camera
# 29                                  Sophia Bioscience
# ..                                                ...
# 200                                             Qcept
# 201                                         Verificon
# 202                                      Swamp Optics
# 203                                  Ample Biometrics
# 204                                   Bionic Sciences
# 205          Kidney Injury Dysfunction Support (KIDS)
# 206                                  General Genomics
# 207                                 Molecular Imaging
# 208                                            Stheno
# 209                                         MoQuality
# 210                                           Soneter
# 211  Rapid discovery of anti-viral drug against Ebola
# 212                                 Skytree Analytics
# 213                                    Digital Vision
# 214       Ultra-high energy density sol-gel ultracaps
# 215                              IC Probing Interface
# 216                                           Qualtre
# 217                                       CellectCell
# 218                                         Piezodyne
# 219                                       Eleon Power
# 220                                          Cognopsi
# 221                                           AxoTect
# 222                                        Vivonetics
# 223                       Tissue Interrogation Device
# 224                                           Carbice
# 225                                               LSQ
# 226                            Clean Hands Safe Hands
# 227                                         RelMaster
# 228                                           InSiAva
# 229                                   Verco Materials
#
#                                             origin first_touch_date  \
# 0    School of Electrical and Computer Engineering       2004-07-01
# 1                 School of Mechanical Engineering       2016-03-14
# 2             Department of Biomedical Engineering       2010-08-16
# 3             Department of Biomedical Engineering       2005-01-01
# 4                       School of Computer Science       2012-06-04
# 5    School of Electrical and Computer Engineering       2013-01-29
# 6    School of Electrical and Computer Engineering       2014-10-01
# 7                             College of Computing       2006-12-01
# 8                             College of Computing       2009-09-22
# 9                  School of Interactive Computing       2015-11-03
# 10            Department of Biomedical Engineering       2008-03-31
# 11           School of Applied Biological Sciences       2011-10-24
# 12                School of Mechanical Engineering       2005-01-01
# 13   School of Electrical and Computer Engineering       2008-04-28
# 14                                             NaN       2015-01-01
# 15                 School of Aerospace Engineering       2015-07-01
# 16   School of Electrical and Computer Engineering       2008-08-08
# 17                 School of Aerospace Engineering       2006-01-01
# 18            Georgia Tech Manufacturing Institute       2008-10-27
# 19            Department of Biomedical Engineering       2014-07-01
# 20                 School of Aerospace Engineering       2012-01-19
# 21                            College of Computing       2012-04-02
# 22                School of Mechanical Engineering       2015-10-01
# 23                                            GTRI       2014-02-10
# 24                      School of Computer Science       2007-06-30
# 25              School of Chemistry & Biochemistry       2014-04-27
# 26                                             NaN       2014-03-10
# 27   School of Electrical and Computer Engineering       2016-03-14
# 28   School of Electrical and Computer Engineering       2013-07-01
# 29              School of Chemistry & Biochemistry       2012-06-01
# ..                                             ...              ...
# 200               School of Mechanical Engineering       2002-06-30
# 201  School of Electrical and Computer Engineering       2008-01-01
# 202                              School of Physics       2014-07-18
# 203                                            NaN       2015-01-01
# 204  School of Electrical and Computer Engineering       2013-07-15
# 205           Department of Biomedical Engineering       2014-02-10
# 206          School of Applied Biological Sciences       2010-11-12
# 207           Department of Biomedical Engineering       2005-01-01
# 208                              School of Physics       2008-04-04
# 209                           College of Computing       2014-05-15
# 210  School of Electrical and Computer Engineering       2010-08-18
# 211          School of Applied Biological Sciences       2015-08-19
# 212                           College of Computing       2008-11-26
# 213                                           GTRI       2009-09-21
# 214             School of Chemistry & Biochemistry       2016-01-07
# 215  School of Electrical and Computer Engineering       2015-10-25
# 216  School of Electrical and Computer Engineering       2006-01-01
# 217               School of Mechanical Engineering       2014-02-10
# 218    School of Materials Science and Engineering       2006-08-01
# 219             School of Chemistry & Biochemistry       2006-01-01
# 220                           College of Computing       2015-07-01
# 221             School of Chemistry & Biochemistry       2006-01-01
# 222           Department of Biomedical Engineering       2003-06-30
# 223           Department of Biomedical Engineering       2009-11-23
# 224               School of Mechanical Engineering       2012-05-31
# 225                           College of Computing       2012-11-20
# 226           Department of Biomedical Engineering       2013-11-08
# 227  School of Electrical and Computer Engineering       2015-12-04
# 228  School of Electrical and Computer Engineering       2006-12-01
# 229    School of Materials Science and Engineering       2005-01-01
#
#     incorporated_date icorps_inv_date icorps_end_date gra_1_inv_date  \
# 0                 NaT             NaN             NaT     2005-01-01
# 1                 NaT             NaN      2016-05-20            NaT
# 2                 NaT             NaN             NaT     2010-09-13
# 3                 NaT             NaN             NaT            NaT
# 4                 NaT      2012-07-01      2012-12-31            NaT
# 5                 NaT             NaN             NaT            NaT
# 6          2016-02-26      2014-10-01      2015-03-31            NaT
# 7                 NaT             NaN             NaT     2006-12-01
# 8                 NaT             NaN             NaT     2009-10-26
# 9                 NaT             NaN      2016-03-04            NaT
# 10                NaT             NaN             NaT            NaT
# 11                NaT             NaN             NaT     2012-01-23
# 12                NaT             NaN             NaT     2005-01-01
# 13                NaT             NaN             NaT     2009-07-29
# 14                NaT             NaN             NaT            NaT
# 15         2014-10-22      2015-07-01      2015-12-31            NaT
# 16                NaT             NaN             NaT     2008-11-20
# 17                NaT             NaN             NaT     2006-01-01
# 18                NaT             NaN             NaT     2008-11-20
# 19                NaT             NaN             NaT            NaT
# 20         2012-03-12             NaN             NaT     2012-02-27
# 21                NaT             NaN             NaT     2012-04-02
# 22                NaT      2015-10-01      2016-03-31     2016-06-07
# 23         2013-10-16             NaN             NaT     2014-11-01
# 24                NaT             NaN             NaT            NaT
# 25                NaT             NaN             NaT     2014-08-20
# 26                NaT             NaN             NaT     2014-03-10
# 27                NaT             NaN      2016-05-17            NaT
# 28                NaT      2013-07-01      2013-12-31     2014-08-20
# 29         2012-10-23             NaN             NaT     2012-07-16
# ..                ...             ...             ...            ...
# 200               NaT             NaN             NaT            NaT
# 201               NaT             NaN             NaT            NaT
# 202        2001-10-12             NaN             NaT            NaT
# 203               NaT             NaN             NaT            NaT
# 204        2012-07-17             NaN             NaT     2013-10-03
# 205               NaT             NaN             NaT     2014-07-10
# 206        2010-10-06             NaN             NaT     2010-11-12
# 207               NaT             NaN             NaT     2005-01-01
# 208               NaT             NaN             NaT            NaT
# 209        2015-11-15      2015-04-01      2015-09-30     2014-08-15
# 210        2010-04-08             NaN             NaT     2010-09-13
# 211               NaT             NaN             NaT     2015-08-19
# 212        2011-08-15             NaN             NaT            NaT
# 213               NaT             NaN             NaT            NaT
# 214               NaT             NaN             NaT            NaT
# 215               NaT             NaN      2016-02-23            NaT
# 216               NaT             NaN             NaT     2006-01-01
# 217        2015-02-13             NaN             NaT     2014-07-14
# 218               NaT             NaN             NaT     2006-08-01
# 219               NaT             NaN             NaT            NaT
# 220               NaT      2015-07-01      2015-12-31            NaT
# 221               NaT             NaN             NaT            NaT
# 222               NaT             NaN             NaT            NaT
# 223               NaT             NaN             NaT     2010-08-04
# 224        2012-01-30             NaN             NaT     2012-07-16
# 225               NaT      2013-04-01      2013-09-30            NaT
# 226        2013-06-17             NaN             NaT     2014-04-11
# 227               NaT             NaN             NaT            NaT
# 228               NaT             NaN             NaT     2006-12-01
# 229               NaT             NaN             NaT     2005-01-01
#
#     gra_2_inv_date gra_3_inv_date sbir_inv_date  total_investments  \
# 0              NaT            NaT           NaT         36290000.0
# 1              NaT            NaT           NaT            50000.0
# 2              NaT            NaT           NaT            25000.0
# 3              NaT            NaT           NaT           240000.0
# 4              NaT            NaT           NaT            50000.0
# 5              NaT            NaT           NaT            25000.0
# 6              NaT            NaT           NaT            50000.0
# 7              NaT            NaT           NaT           200000.0
# 8              NaT            NaT           NaT            43000.0
# 9              NaT            NaT           NaT            50000.0
# 10             NaT            NaT           NaT            50000.0
# 11             NaT            NaT           NaT             6000.0
# 12             NaT            NaT           NaT            35000.0
# 13             NaT            NaT           NaT            47000.0
# 14             NaT            NaT           NaT            15000.0
# 15             NaT            NaT           NaT            50000.0
# 16             NaT            NaT           NaT            60000.0
# 17      2008-12-01            NaT           NaT           368300.0
# 18             NaT            NaT           NaT            50000.0
# 19             NaT            NaT           NaT          6760000.0
# 20      2014-02-27            NaT    2014-07-01          1023563.0
# 21             NaT            NaT           NaT            36000.0
# 22             NaT            NaT           NaT            75000.0
# 23             NaT            NaT           NaT          3550000.0
# 24             NaT     2008-09-16           NaT          1600000.0
# 25             NaT            NaT           NaT            50000.0
# 26             NaT            NaT           NaT            25000.0
# 27             NaT            NaT           NaT            50000.0
# 28             NaT            NaT           NaT            99869.0
# 29             NaT            NaT           NaT           302900.0
# ..             ...            ...           ...                ...
# 200            NaT            NaT           NaT         41620001.0
# 201            NaT            NaT           NaT           270000.0
# 202     2014-09-11            NaT           NaT           150000.0
# 203            NaT            NaT           NaT             5000.0
# 204            NaT            NaT           NaT           249888.0
# 205            NaT            NaT           NaT           200000.0
# 206     2014-03-10            NaT           NaT           616735.0
# 207            NaT            NaT           NaT            50000.0
# 208            NaT            NaT           NaT           800000.0
# 209            NaT            NaT           NaT           299877.0
# 210     2012-02-20     2013-04-29           NaT          6544500.0
# 211            NaT            NaT           NaT            13338.0
# 212            NaT            NaT           NaT         21508000.0
# 213     2010-03-23     2011-12-13           NaT           350000.0
# 214            NaT            NaT           NaT            25000.0
# 215            NaT            NaT           NaT            50000.0
# 216     2006-08-01            NaT           NaT         15500000.0
# 217     2015-09-10            NaT           NaT           219775.0
# 218            NaT            NaT           NaT            75000.0
# 219            NaT            NaT           NaT          1127000.0
# 220            NaT            NaT           NaT           121000.0
# 221     2006-01-01     2010-11-17           NaT           549979.0
# 222            NaT            NaT    2003-06-30          1948000.0
# 223            NaT            NaT           NaT            70000.0
# 224     2015-02-18            NaT    2014-11-01           577101.0
# 225            NaT            NaT           NaT            50000.0
# 226     2014-09-10     2015-05-07           NaT           380000.0
# 227            NaT            NaT           NaT            25000.0
# 228            NaT            NaT           NaT            50000.0
# 229     2006-01-01            NaT           NaT          4135000.0
#
#      touch_to_gra_1_days  icorps_to_gra_1_days  gra_1_to_gra_2_days  \
# 0                  184.0                   NaN                  NaN
# 1                    NaN                   NaN                  NaN
# 2                   28.0                   NaN                  NaN
# 3                    NaN                   NaN                  NaN
# 4                    NaN                   NaN                  NaN
# 5                    NaN                   NaN                  NaN
# 6                    NaN                   NaN                  NaN
# 7                    0.0                   NaN                  NaN
# 8                   34.0                   NaN                  NaN
# 9                    NaN                   NaN                  NaN
# 10                   NaN                   NaN                  NaN
# 11                  91.0                   NaN                  NaN
# 12                   0.0                   NaN                  NaN
# 13                 457.0                   NaN                  NaN
# 14                   NaN                   NaN                  NaN
# 15                   NaN                   NaN                  NaN
# 16                 104.0                   NaN                  NaN
# 17                   0.0                   NaN               1065.0
# 18                  24.0                   NaN                  NaN
# 19                   NaN                   NaN                  NaN
# 20                  39.0                   NaN                731.0
# 21                   0.0                   NaN                  NaN
# 22                 250.0                  68.0                  NaN
# 23                 264.0                   NaN                  NaN
# 24                   NaN                   NaN                  NaN
# 25                 115.0                   NaN                  NaN
# 26                   0.0                   NaN                  NaN
# 27                   NaN                   NaN                  NaN
# 28                 415.0                 232.0                  NaN
# 29                  45.0                   NaN                  NaN
# ..                   ...                   ...                  ...
# 200                  NaN                   NaN                  NaN
# 201                  NaN                   NaN                  NaN
# 202                  NaN                   NaN                  NaN
# 203                  NaN                   NaN                  NaN
# 204                 80.0                   NaN                  NaN
# 205                150.0                   NaN                  NaN
# 206                  0.0                   NaN               1214.0
# 207                  0.0                   NaN                  NaN
# 208                  NaN                   NaN                  NaN
# 209                 92.0                -411.0                  NaN
# 210                 26.0                   NaN                525.0
# 211                  0.0                   NaN                  NaN
# 212                  NaN                   NaN                  NaN
# 213                  NaN                   NaN                  NaN
# 214                  NaN                   NaN                  NaN
# 215                  NaN                   NaN                  NaN
# 216                  0.0                   NaN                212.0
# 217                154.0                   NaN                423.0
# 218                  0.0                   NaN                  NaN
# 219                  NaN                   NaN                  NaN
# 220                  NaN                   NaN                  NaN
# 221                  NaN                   NaN                  NaN
# 222                  NaN                   NaN                  NaN
# 223                254.0                   NaN                  NaN
# 224                 46.0                   NaN                947.0
# 225                  NaN                   NaN                  NaN
# 226                154.0                   NaN                152.0
# 227                  NaN                   NaN                  NaN
# 228                  0.0                   NaN                  NaN
# 229                  0.0                   NaN                365.0
#
#      gra_2_to_gra_3_days
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# ..                   ...
# 200                  NaN
# 201                  NaN
# 202                  NaN
# 203                  NaN
# 204                  NaN
# 205                  NaN
# 206                  NaN
# 207                  NaN
# 208                  NaN
# 209                  NaN
# 210                434.0
# 211                  NaN
# 212                  NaN
# 213                630.0
# 214                  NaN
# 215                  NaN
# 216                  NaN
# 217                  NaN
# 218                  NaN
# 219                  NaN
# 220                  NaN
# 221               1781.0
# 222                  NaN
# 223                  NaN
# 224                  NaN
# 225                  NaN
# 226                239.0
# 227                  NaN
# 228                  NaN
# 229                  NaN
#
# [230 rows x 15 columns]

# %%
def export_as_csv(df, fn):
    with open('data_out/' + fn, 'w') as outcsv:
        df.to_csv(outcsv)

# %%
# Slice the subsets -- teams before I-Corps was founded, post-founding teams 
# that did not participate, and teams that did participate.
pre_icorps = df[df.first_touch_date > icorps_start_date]
no_icorps = df[(df.first_touch_date <= icorps_start_date) & (pandas.isnull(df.icorps_end_date))]
did_icorps = df[pandas.notnull(df.icorps_end_date)]

# %%
# How many of each are there?
len(pre_icorps), len(no_icorps), len(did_icorps)
# Out:
# (91, 136, 43)

# %%
# Save the whole file plus the subsets.
export_as_csv(df, 'all_startups.csv')
export_as_csv(pre_icorps, 'pre_icorps.csv')
export_as_csv(no_icorps, 'no_icorps.csv')
export_as_csv(did_icorps, 'did_icorps.csv')

# %%
# Define some convenient functions to give us the intervals we're interested in for each subset.
def avg_days(s):
    return round(s.mean(), 0)
def day_metrics(df):
    return avg_days(df.touch_to_gra_1_days), \
            avg_days(df.icorps_to_gra_1_days), \
            avg_days(df.gra_1_to_gra_2_days), \
            avg_days(df.gra_2_to_gra_3_days)

# %%
# averages: from first touch to GRA 1, from end of I-Corps to GR1,from GRA 1 to GRA 2, from GRA 2 to GRA 3

# %%
day_metrics(pre_icorps)
# Out:
# (180.0, 52.0, 529.0, 358.0)

# %%
day_metrics(no_icorps)
# Out:
# (118.0, nan, 490.0, 559.0)

# %%
day_metrics(did_icorps)
# Out:
# (280.0, -151.0, 804.0, nan)
